% %% [markdown]
% # Neural network inference via invariant prediction, part deux
% Here we infer a set of connections in the presence of hidden units by taking advantage of the different statistics exhibited by direct and indirect connections under changes in environment (common input).
%
% In part 1 we demonstrated the idea of our project -- simulating spike trains and using GLMs to infer connectivity. In this notebook we generate a lot of different spiking data using the method from
%
% `"Emergence of network structure due to spike-timing-dependent plasticity in recurrent neuronal networks. I. Input selectivity–strengthening correlated input pathways." Matthieu GilsonEmail authorAnthony N. BurkittDavid B. GraydenDoreen A. ThomasJ. Leo van Hemmen. Biological Cybernetics
% August 2009, Volume 101, Issue 2, pp 81–102`

% %%
%Add things to path
startup

% %% [markdown]
% We set networks of different sizes and generate spike trains. The external stimulation only goes to 'hidden' neurons, thus we set two parameters: the size of the network, N, and the number of hidden neurons, Q. The remaining neurons are observed.

% %%
%20 seconds of test data
indirect_stim_population(9, 9, 20, 'testout');
% Out:
% Processing batch # 1/1
% Processing batch # 1/1-->10% complete
% Processing batch # 1/1-->20% complete
% Processing batch # 1/1-->30% complete
% Processing batch # 1/1-->40% complete
% Processing batch # 1/1-->50% complete
% Processing batch # 1/1-->60% complete
% Processing batch # 1/1-->70% complete
% Processing batch # 1/1-->80% complete
% Processing batch # 1/1-->90% complete
% Elapsed time is 21.461338 seconds.

% %%
%We run the remaining network sims
indirect_stim_population(30, 30, 600, 'netsim_n_30_q_30_t_600');
indirect_stim_population(30, 21, 600, 'netsim_n_30_q_21_t_600');
indirect_stim_population(30, 12, 600, 'netsim_n_30_q_12_t_600');

indirect_stim_population(60, 60, 600, 'netsim_n_60_q_60_t_600');
indirect_stim_population(60, 51, 600, 'netsim_n_60_q_51_t_600');
indirect_stim_population(60, 42, 600, 'netsim_n_60_q_42_t_600');

indirect_stim_population(90, 90, 600, 'netsim_n_90_q_90_t_600');
indirect_stim_population(90, 81, 600, 'netsim_n_90_q_81_t_600');
indirect_stim_population(90, 72, 600, 'netsim_n_90_q_72_t_600');

indirect_stim_population(120, 120, 600, 'netsim_n_120_q_120_t_600');
indirect_stim_population(120, 111, 600, 'netsim_n_120_q_111_t_600');
indirect_stim_population(120, 102, 600, 'netsim_n_120_q_102_t_600');
